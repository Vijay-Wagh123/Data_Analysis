# %% [markdown]
# [Download Dataset](https://www.kaggle.com/kaggle/sf-salaries)

# %%
import pandas as pd
import matplotlib.pyplot as py

# %%
data = pd.read_csv("C:\\Users\\vijay wagh\\Desktop\\udemy_dataset\\udemy_courses.csv")

# %% [markdown]
# ### 1.Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#       course_id                                       course_title  \
# 3668     270976                             A how to guide in HTML
# 3669     679992                  Building Better APIs with GraphQL
# 3670     330900  Learn Grunt with Examples: Automate Your Front...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3672     865438    jQuery UI in Action: Build 5 jQuery UI Projects
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3668      https://www.udemy.com/a-how-to-guide-in-html/    False      0
# 3669  https://www.udemy.com/building-better-apis-wit...     True     50
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (3678, 12)

# %%
print("Number of rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of rows 3678
# Number of columns 12

# %% [markdown]
# ### 4. Getting Information About Our Dataset Like Total Number Rows,
# ### Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %% [markdown]
# ### 5. Check for duplicates and drop them

# %%
temp=data.duplicated().any()
print("Duplicates present",temp)
data.drop_duplicates(inplace=True)
temp=data.duplicated().any()
print("Duplicates present",temp)
# Out:
# Duplicates present True
# Duplicates present False

# %% [markdown]
# ### 6. Find out number of courses per subject

# %%
data.columns
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
temp=data['subject'].value_counts()
py.plot(temp)
py.xlabel("subject")
py.ylabel("No of courses")
py.title("No of courses per subject")
py.show()

# %% [markdown]
# ### 8. For which level udemy providing the courses

# %%
data.columns
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
temp=data['level'].value_counts()
py.bar(temp.index,temp.values)
py.ylabel("count")
py.title("Levels")
py.xticks(rotation=45)
py.show()

# %% [markdown]
# ### 9. Find count of paid and free courses

# %%
data.columns
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %% [markdown]
# ### 11. Which courses have large number of subscriber(Free or Paid)

# %%
data_grouped = data.groupby('is_paid')['num_subscribers'].sum()
data_grouped
# Out:
# is_paid
# False    3575525
# True     8140310
# Name: num_subscribers, dtype: int64

# %% [markdown]
# ### 12. Find last row of dataset

# %%
data.tail(1)
# Out:
#       course_id                                       course_title  \
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 3677              901           36            20  Beginner Level
#
#       content_duration   published_timestamp          subject
# 3677               2.0  2014-09-28T19:51:11Z  Web Development

# %% [markdown]
# ### 13. print only subject column

# %%
print("subject")
print(data['subject'].to_string(index=False))
# Out:
# subject
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
#    Business Finance
# ...

# %% [markdown]
# ### 14. Drop the price column

# %%
data=data.drop("price",axis=1)
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True
# ...

# %% [markdown]
# ### 15. Find maximum ,minimum number of subscriber from subscriber column and top five courses with max subscriber

# %%
max(data['num_subscribers'])
# Out:
# 268923

# %%
min(data['num_subscribers'])
# Out:
# 0

# %%
temp=data.sort_values(by='num_subscribers',ascending=False)
temp[['course_title','num_subscribers']].head(5)
# Out:
#                                            course_title  num_subscribers
# 2827               Learn HTML5 Programming From Scratch           268923
# 3032                     Coding for Entrepreneurs Basic           161029
# 3230                         The Web Developer Bootcamp           121584
# 2783  Build Your First Website in 1 Week with HTML5 ...           120291
# 3232              The Complete Web Developer Course 2.0           114512
